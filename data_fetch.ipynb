# %%
from pybaseball import statcast

# %%
# %cd C:/Users/citioplab/works/codes/baseball_projects/

# %%
data_2025 = statcast('2025-03-18', '2025-07-14')

# %%
data_2025.to_csv('./data/2025_data.csv', index = False)
